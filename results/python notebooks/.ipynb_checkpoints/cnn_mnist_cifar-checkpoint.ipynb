# %%
# mnist on cnn with 2 layers

# %%
from convo_2_layers import *
# Out:
# Using gpu device 0: GRID K520

# %%
#linear dropout
test_lenet(learning_rate= 0.1, n_epochs=100, nkerns=[32,64,150], filter_shapes=[[3,3],[2,2]], pool_sizes=[[2,2],[1,1]],ignore_border=[False,False],batch_size = 128, verbose = True,smaller_set= False, activation =linear_rectifier,p= 0.5,dataset= 'MNIST',hidden_layer_type = DropoutHiddenLayer,momentum = 0,crop = False,rotate = False)
# Out:
# crop : False rotate : False
# train_set_x shape : (50000, 784)
# test_set_x shape : (10000, 784)
# valid_set_x shape : (10000, 784)
# n_train_batches : 390
# n_test_batches : 78
# n_valid_batches : 78
# ... building the model
# layer 0 end :  [13, 13]  nkerns : 32
# layer 1 end :  [12, 12]  nkerns : 64
# layer 2 begin :  9216
# layer 2 end :  150
# Model build.
# ... training
# momentum:  0.0
# learning rate:  0.1
# epoch 1, minibatch 390/390, validation error 10.797276 %
#      epoch 1, minibatch 390/390, test error of best model 11.638622 %
# momentum:  0.019999999553
# learning rate:  0.0985
# epoch 2, minibatch 390/390, validation error 5.618990 %
#      epoch 2, minibatch 390/390, test error of best model 5.649038 %
# momentum:  0.0395999997854
# learning rate:  0.0970225
# epoch 3, minibatch 390/390, validation error 4.457131 %
#      epoch 3, minibatch 390/390, test error of best model 4.747596 %
# momentum:  0.0588079988956
# learning rate:  0.0955671625
# ...

# %%
#linear dropout crop 
test_lenet(learning_rate= 0.1, n_epochs=100, nkerns=[32,64,150], filter_shapes=[[3,3],[2,2]], pool_sizes=[[2,2],[1,1]],ignore_border=[False,False],batch_size = 128, verbose = True,smaller_set= False, activation =linear_rectifier,p= 0.5,dataset= 'MNIST',hidden_layer_type = DropoutHiddenLayer,momentum = 0,crop = True,rotate = False)
# Out:
# crop : True rotate : False
# train_set_x shape : (50000, 576)
# test_set_x shape : (10000, 576)
# valid_set_x shape : (10000, 576)
# n_train_batches : 390
# n_test_batches : 78
# n_valid_batches : 78
# ... building the model
# layer 0 end :  [11, 11]  nkerns : 32
# layer 1 end :  [10, 10]  nkerns : 64
# layer 2 begin :  6400
# layer 2 end :  150
# Model build.
# ... training
# momentum:  0.0
# learning rate:  0.1
# epoch 1, minibatch 390/390, validation error 27.744391 %
#      epoch 1, minibatch 390/390, test error of best model 28.495593 %
# momentum:  0.019999999553
# learning rate:  0.0985
# epoch 2, minibatch 390/390, validation error 11.278045 %
#      epoch 2, minibatch 390/390, test error of best model 11.408253 %
# momentum:  0.0395999997854
# learning rate:  0.0970225
# epoch 3, minibatch 390/390, validation error 7.041266 %
#      epoch 3, minibatch 390/390, test error of best model 7.031250 %
# momentum:  0.0588079988956
# learning rate:  0.0955671625
# ...

# %%
#linear dropout crop and rotate
test_lenet(learning_rate= 0.1, n_epochs=100, nkerns=[32,64,150], filter_shapes=[[3,3],[2,2]], pool_sizes=[[2,2],[1,1]],ignore_border=[False,False],batch_size = 128, verbose = True,smaller_set= False, activation =linear_rectifier,p= 0.5,dataset= 'MNIST',hidden_layer_type = DropoutHiddenLayer,momentum = 0,crop = True,rotate = True)
# Out:
# crop : True rotate : True
# train_set_x shape : (50000, 576)
# test_set_x shape : (10000, 576)
# valid_set_x shape : (10000, 576)
# n_train_batches : 390
# n_test_batches : 78
# n_valid_batches : 78
# ... building the model
# layer 0 end :  [11, 11]  nkerns : 32
# layer 1 end :  [10, 10]  nkerns : 64
# layer 2 begin :  6400
# layer 2 end :  150
# Model build.
# ... training
# momentum:  0.0
# learning rate:  0.1
# epoch 1, minibatch 390/390, validation error 57.281651 %
#      epoch 1, minibatch 390/390, test error of best model 57.431891 %
# momentum:  0.019999999553
# learning rate:  0.0985
# epoch 2, minibatch 390/390, validation error 39.132612 %
#      epoch 2, minibatch 390/390, test error of best model 40.234375 %
# momentum:  0.0395999997854
# learning rate:  0.0970225
# epoch 3, minibatch 390/390, validation error 30.238381 %
#      epoch 3, minibatch 390/390, test error of best model 30.989583 %
# momentum:  0.0588079988956
# learning rate:  0.0955671625
# ...

# %%
#linear no-drop
test_lenet(learning_rate= 0.1, n_epochs=100, nkerns=[32,64,150], filter_shapes=[[3,3],[2,2]], pool_sizes=[[2,2],[1,1]],ignore_border=[False,False],batch_size = 128, verbose = True,smaller_set= False, activation =linear_rectifier,p= 1,dataset= 'MNIST',hidden_layer_type = DropoutHiddenLayer,momentum = 0,crop = False,rotate = False)
# Out:
# crop : False rotate : False
# train_set_x shape : (50000, 784)
# test_set_x shape : (10000, 784)
# valid_set_x shape : (10000, 784)
# n_train_batches : 390
# n_test_batches : 78
# n_valid_batches : 78
# ... building the model
# layer 0 end :  [13, 13]  nkerns : 32
# layer 1 end :  [12, 12]  nkerns : 64
# layer 2 begin :  9216
# layer 2 end :  150
# Model build.
# ... training
# momentum:  0.0
# learning rate:  0.1
# epoch 1, minibatch 390/390, validation error 7.161458 %
#      epoch 1, minibatch 390/390, test error of best model 7.251603 %
# momentum:  0.019999999553
# learning rate:  0.0985
# epoch 2, minibatch 390/390, validation error 4.016426 %
#      epoch 2, minibatch 390/390, test error of best model 4.397035 %
# momentum:  0.0395999997854
# learning rate:  0.0970225
# epoch 3, minibatch 390/390, validation error 2.864583 %
#      epoch 3, minibatch 390/390, test error of best model 2.874599 %
# momentum:  0.0588079988956
# learning rate:  0.0955671625
# ...

# %%
#linear no-drop crop
test_lenet(learning_rate= 0.1, n_epochs=100, nkerns=[32,64,150], filter_shapes=[[3,3],[2,2]], pool_sizes=[[2,2],[1,1]],ignore_border=[False,False],batch_size = 128, verbose = True,smaller_set= False, activation =linear_rectifier,p= 1,dataset= 'MNIST',hidden_layer_type = DropoutHiddenLayer,momentum = 0,crop = True,rotate = False)
# Out:
# crop : True rotate : False
# train_set_x shape : (50000, 576)
# test_set_x shape : (10000, 576)
# valid_set_x shape : (10000, 576)
# n_train_batches : 390
# n_test_batches : 78
# n_valid_batches : 78
# ... building the model
# layer 0 end :  [11, 11]  nkerns : 32
# layer 1 end :  [10, 10]  nkerns : 64
# layer 2 begin :  6400
# layer 2 end :  150
# Model build.
# ... training
# momentum:  0.0
# learning rate:  0.1
# epoch 1, minibatch 390/390, validation error 22.155449 %
#      epoch 1, minibatch 390/390, test error of best model 23.437500 %
# momentum:  0.019999999553
# learning rate:  0.0985
# epoch 2, minibatch 390/390, validation error 5.508814 %
#      epoch 2, minibatch 390/390, test error of best model 5.709135 %
# momentum:  0.0395999997854
# learning rate:  0.0970225
# epoch 3, minibatch 390/390, validation error 3.976362 %
#      epoch 3, minibatch 390/390, test error of best model 4.196715 %
# momentum:  0.0588079988956
# learning rate:  0.0955671625
# ...

# %%
#linear no-drop crop and rotate
test_lenet(learning_rate= 0.1, n_epochs=100, nkerns=[32,64,150], filter_shapes=[[3,3],[2,2]], pool_sizes=[[2,2],[1,1]],ignore_border=[False,False],batch_size = 128, verbose = True,smaller_set= False, activation =linear_rectifier,p= 1,dataset= 'MNIST',hidden_layer_type = DropoutHiddenLayer,momentum = 0,crop = True,rotate = True)
# Out:
# crop : True rotate : True
# train_set_x shape : (50000, 576)
# test_set_x shape : (10000, 576)
# valid_set_x shape : (10000, 576)
# n_train_batches : 390
# n_test_batches : 78
# n_valid_batches : 78
# ... building the model
# layer 0 end :  [11, 11]  nkerns : 32
# layer 1 end :  [10, 10]  nkerns : 64
# layer 2 begin :  6400
# layer 2 end :  150
# Model build.
# ... training
# momentum:  0.0
# learning rate:  0.1
# epoch 1, minibatch 390/390, validation error 56.320112 %
#      epoch 1, minibatch 390/390, test error of best model 56.390224 %
# momentum:  0.019999999553
# learning rate:  0.0985
# epoch 2, minibatch 390/390, validation error 31.179888 %
#      epoch 2, minibatch 390/390, test error of best model 31.690705 %
# momentum:  0.0395999997854
# learning rate:  0.0970225
# epoch 3, minibatch 390/390, validation error 16.496394 %
#      epoch 3, minibatch 390/390, test error of best model 16.105769 %
# momentum:  0.0588079988956
# learning rate:  0.0955671625
# ...
