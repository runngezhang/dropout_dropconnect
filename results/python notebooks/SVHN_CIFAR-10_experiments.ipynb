# %%
from convo_3_layers import *
# Out:
# Using gpu device 0: GRID K520

# %%
# SVHN DROPOUT 
test_lenet(learning_rate= 0.1, n_epochs=700, nkerns=[16,64,20,300], filter_shapes=[[3,3],[2,2],[1,1]], pool_sizes=[[2,2],[2,2],[1,1]],ignore_border=[False,False,False],batch_size = 128, verbose = True, smaller_set= False, activation =linear_rectifier, p= 0.5, dataset= 'SVHN', hidden_layer_type = DropoutHiddenLayer, momentum = 0,crop = False,rotate = False)
# Out:
# train_set_x shape : (65932, 3072)
# test_set_x shape : (26032, 3072)
# valid_set_x shape : (7325, 3072)
# n_train_batches : 515
# n_test_batches : 203
# n_valid_batches : 57
# ... building the model
# layer 0 end :  [15, 15]  nkerns : 16
# layer 1 end :  [7, 7]  nkerns : 64
# layer 2 end :  [7, 7]  nkerns : 20
# layer 2 begin :  980
# layer 2 end :  300
# Model build.
# ... training
# momentum:  0.0
# learning rate:  0.1
# epoch 1, minibatch 515/515, validation error 81.154057 %
#      epoch 1, minibatch 515/515, test error of best model 80.414871 %
# momentum:  0.019999999553
# learning rate:  0.0985
# epoch 2, minibatch 515/515, validation error 81.044408 %
#      epoch 2, minibatch 515/515, test error of best model 80.233990 %
# momentum:  0.0395999997854
# learning rate:  0.0970225
# epoch 3, minibatch 515/515, validation error 76.370614 %
#      epoch 3, minibatch 515/515, test error of best model 74.291872 %
# momentum:  0.0588079988956
# learning rate:  0.0955671625
# ...

# %%
# CIFAR-10 DROPOUT
test_lenet(learning_rate= 0.1, n_epochs=100, nkerns=[16,64,20,300], filter_shapes=[[3,3],[2,2],[1,1]], pool_sizes=[[2,2],[2,2],[1,1]],ignore_border=[False,False,False],batch_size = 128, verbose = True, smaller_set= False, activation =linear_rectifier, p= 0.5, dataset= 'CIFAR-10', hidden_layer_type = DropoutHiddenLayer, momentum = 0,crop = False,rotate = False)
# Out:
# train_set_x shape : (45000, 3072)
# test_set_x shape : (10000, 3072)
# valid_set_x shape : (5000, 3072)
# n_train_batches : 351
# n_test_batches : 78
# n_valid_batches : 39
# ... building the model
# layer 0 end :  [15, 15]  nkerns : 16
# layer 1 end :  [7, 7]  nkerns : 64
# layer 2 end :  [7, 7]  nkerns : 20
# layer 2 begin :  980
# layer 2 end :  300
# Model build.
# ... training
# momentum:  0.0
# learning rate:  0.1
# epoch 1, minibatch 351/351, validation error 71.754808 %
#      epoch 1, minibatch 351/351, test error of best model 70.893429 %
# momentum:  0.019999999553
# learning rate:  0.0985
# epoch 2, minibatch 351/351, validation error 59.815705 %
#      epoch 2, minibatch 351/351, test error of best model 58.934295 %
# momentum:  0.0395999997854
# learning rate:  0.0970225
# epoch 3, minibatch 351/351, validation error 56.670673 %
#      epoch 3, minibatch 351/351, test error of best model 55.018029 %
# momentum:  0.0588079988956
# learning rate:  0.0955671625
# ...

# %%
# SVHN no-drop
test_lenet(learning_rate= 0.1, n_epochs=100, nkerns=[16,64,20,300], filter_shapes=[[3,3],[2,2],[1,1]], pool_sizes=[[2,2],[2,2],[1,1]],ignore_border=[False,False,False],batch_size = 128, verbose = True, smaller_set= False, activation =linear_rectifier, p= 1, dataset= 'SVHN', hidden_layer_type = DropoutHiddenLayer, momentum = 0,crop = False,rotate = False)
# Out:
# train_set_x shape : (65932, 3072)
# test_set_x shape : (26032, 3072)
# valid_set_x shape : (7325, 3072)
# n_train_batches : 515
# n_test_batches : 203
# n_valid_batches : 57
# ... building the model
# layer 0 end :  [15, 15]  nkerns : 16
# layer 1 end :  [7, 7]  nkerns : 64
# layer 2 end :  [7, 7]  nkerns : 20
# layer 2 begin :  980
# layer 2 end :  300
# Model build.
# ... training
# momentum:  0.0
# learning rate:  0.1
# epoch 1, minibatch 515/515, validation error 81.085526 %
#      epoch 1, minibatch 515/515, test error of best model 80.376385 %
# momentum:  0.019999999553
# learning rate:  0.0985
# epoch 2, minibatch 515/515, validation error 67.859101 %
#      epoch 2, minibatch 515/515, test error of best model 65.959821 %
# momentum:  0.0395999997854
# learning rate:  0.0970225
# epoch 3, minibatch 515/515, validation error 56.496711 %
#      epoch 3, minibatch 515/515, test error of best model 53.694581 %
# momentum:  0.0588079988956
# learning rate:  0.0955671625
# ...

# %%
#CIFAR No-drop
test_lenet(learning_rate= 0.1, n_epochs=100, nkerns=[16,64,20,300], filter_shapes=[[3,3],[2,2],[1,1]], pool_sizes=[[2,2],[2,2],[1,1]],ignore_border=[False,False,False],batch_size = 128, verbose = True, smaller_set= False, activation =linear_rectifier, p= 1, dataset= 'CIFAR-10', hidden_layer_type = DropoutHiddenLayer, momentum = 0,crop = False,rotate = False)
# Out:
# train_set_x shape : (45000, 3072)
# test_set_x shape : (10000, 3072)
# valid_set_x shape : (5000, 3072)
# n_train_batches : 351
# n_test_batches : 78
# n_valid_batches : 39
# ... building the model
# layer 0 end :  [15, 15]  nkerns : 16
# layer 1 end :  [7, 7]  nkerns : 64
# layer 2 end :  [7, 7]  nkerns : 20
# layer 2 begin :  980
# layer 2 end :  300
# Model build.
# ... training
# momentum:  0.0
# learning rate:  0.1
# epoch 1, minibatch 351/351, validation error 70.713141 %
#      epoch 1, minibatch 351/351, test error of best model 70.743189 %
# momentum:  0.019999999553
# learning rate:  0.0985
# epoch 2, minibatch 351/351, validation error 60.096154 %
#      epoch 2, minibatch 351/351, test error of best model 60.016026 %
# momentum:  0.0395999997854
# learning rate:  0.0970225
# epoch 3, minibatch 351/351, validation error 52.103365 %
#      epoch 3, minibatch 351/351, test error of best model 51.392228 %
# momentum:  0.0588079988956
# learning rate:  0.0955671625
# ...

# %%
# SVHN DROPCONNECT
from convo_3_layers import *
test_lenet(learning_rate= 0.1, n_epochs=20, nkerns=[16,64,20,300], filter_shapes=[[3,3],[2,2],[1,1]], pool_sizes=[[2,2],[2,2],[1,1]],ignore_border=[False,False,False],batch_size = 20, verbose = True, smaller_set= False, activation =linear_rectifier, p= 0.5, dataset= 'SVHN', hidden_layer_type = DropconnectHiddenLayer, momentum = 0,crop = False,rotate = False)
# Out:
# train_set_x shape : (65932, 3072)
# test_set_x shape : (26032, 3072)
# valid_set_x shape : (7325, 3072)
# n_train_batches : 3296
# n_test_batches : 1301
# n_valid_batches : 366
# ... building the model
# layer 0 end :  [15, 15]  nkerns : 16
# layer 1 end :  [7, 7]  nkerns : 64
# layer 2 end :  [7, 7]  nkerns : 20
# layer 2 begin :  980
# weighted_masks_shape  [ 20 980 300]
# layer 2 end :  300
# Found.
# Model build.
# ... training
# momentum:  0.0
# learning rate:  0.1
# epoch 1, minibatch 3296/3296, validation error 63.483607 %
#      epoch 1, minibatch 3296/3296, test error of best model 60.084550 %
# momentum:  0.019999999553
# learning rate:  0.0985
# epoch 2, minibatch 3296/3296, validation error 41.734973 %
#      epoch 2, minibatch 3296/3296, test error of best model 41.952344 %
# momentum:  0.0395999997854
# learning rate:  0.0970225
# epoch 3, minibatch 3296/3296, validation error 31.926230 %
#      epoch 3, minibatch 3296/3296, test error of best model 33.873943 %
# ...

# %%
# SVHN DROPCONNECT
from convo_3_layers import *
test_lenet(learning_rate= 0.1, n_epochs=20, nkerns=[16,64,20,300], filter_shapes=[[3,3],[2,2],[1,1]], pool_sizes=[[2,2],[2,2],[1,1]],ignore_border=[False,False,False],batch_size = 20, verbose = True, smaller_set= False, activation =linear_rectifier, p= 0.5, dataset= 'SVHN', hidden_layer_type = DropconnectHiddenLayer, momentum = 0,crop = False,rotate = False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-b284ba09f351> in <module>()
#       1 # SVHN DROPCONNECT
#       2 from convo_3_layers import *
# ----> 3 test_lenet(learning_rate= 0.1, n_epochs=20, nkerns=[16,64,20,300], filter_shapes=[[3,3],[2,2],[1,1]], pool_sizes=[[2,2],[2,2],[1,1]],ignore_border=[False,False,False],batch_size = 20, verbose = True, smaller_set= False, activation =linear_rectifier, p= 0.5, dataset= 'SVHN', hidden_layer_type = DropconnectHiddenLayer, momentum = 0,crop = False,rotate = False)
#
# /home/ubuntu/dl/convo_3_layers.pyc in test_lenet(learning_rate, momentum, n_epochs, nkerns, filter_shapes, pool_sizes, ignore_border, batch_size, verbose, smaller_set, activation, p, dataset, hidden_layer_type, crop, rotate)
#      53         datasets = load_data(ds_rate=35, theano_shared=True,source = dataset,crop = crop,rotate = rotate)
# ...
